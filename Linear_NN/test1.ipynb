# %%
#Author-Vishal Burman

# %% [markdown]
# ## Vectorization for speed

# %%
import numpy as np
import time
import math

# %%
#Lets define two array with size 100000

# %%
n=100000
a=np.ones(n)
b=np.ones(n)

# %%
#One way to add them is to iterate through every one of them

# %%
start=time.time()
c=np.zeros(n)
for i in range(n):
    c[i]=a[i]+b[i]
'%.5f sec' % (time.time() - start)
# Out:
# '0.07519 sec'

# %%
#Another way is to add vectors directly
# As we can see vectorization offers magnitude speedups

# %%
start = time.time()
d = a + b
'%.5f sec' % (time.time() - start)
# Out:
# '0.00000 sec'

# %% [markdown]
# ## The Normal Distribution and Squared Loss

# %%
import matplotlib.pyplot as plt

# %%
#The normal distribution with various means and variances can be viewed as follows

# %%
# %matplotlib inline
#Mean and variance pairs
parameters=[(0,1), (0,2), (3, 1)]
x=np.arange(-7, 7, 0.01)
for (mu, sigma) in parameters:
    p=1/math.sqrt(2*math.pi*sigma**2)
    p=p*np.exp(-0.5/sigma**2*(x-mu)**2)
    plt.plot(x, p, label='mean %d, variance %d' %(mu, sigma))
plt.legend()
